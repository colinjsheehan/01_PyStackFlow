# %% [markdown]
# <a href="https://colab.research.google.com/github/colinjsheehan/01_PyStackFlow/blob/main/01_intro_colab_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
import sys
sys.version
# Out:
# '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

print("Libraries loaded.")
# Out:
# Libraries loaded.

# %%
import pandas as pd

data = {
    "hours_studied": [1, 2, 3, 4, 5, 6],
    "score": [50, 55, 60, 65, 70, 78]
}

df = pd.DataFrame(data)
df
plt.scatter(df["hours_studied"], df["score"])
plt.xlabel("Hours studied")
plt.ylabel("Score")
plt.title("Study time vs score")
plt.show()

# %%
model = LinearRegression()
model.fit(df[["hours_studied"]], df["score"])

print("Coefficient:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Coefficient: 5.428571428571429
# Intercept: 44.0

# %%
model.predict(pd.DataFrame({"hours_studied": [7]}))
# Out:
# array([82.])

# %%
import pandas as pd

data = {
    "hours_studied": [1, 2, 3, 4, 5, 6],
    "score": [50, 55, 60, 65, 70, 78]
}

df = pd.DataFrame(data)
df
# Out:
#    hours_studied  score
# 0              1     50
# 1              2     55
# 2              3     60
# 3              4     65
# 4              5     70
# 5              6     78

# %%
model = LinearRegression()
model.fit(df[["hours_studied"]], df["score"])

print("Coefficient:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Coefficient: 5.428571428571429
# Intercept: 44.0

# %%
model.predict(pd.DataFrame({"hours_studied": [7]}))
# Out:
# array([82.])
